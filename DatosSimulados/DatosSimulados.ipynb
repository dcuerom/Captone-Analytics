# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
ruta01 = r'dcuerom/Captone-Analytics/DatosSimulados/vrp_orders.xlsx'
df = pd.read_excel(ruta01)
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 2
#       1 ruta01 = r'DatosSimulados/vrp_orders.xlsx'
# ----> 2 df = pd.read_excel(ruta01, engine='openpyxl')
#       3 df.head()
#
# File ~/venvs/global/lib/python3.14/site-packages/pandas/io/excel/_base.py:481, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     479 if not isinstance(io, ExcelFile):
#     480     should_close = True
# --> 481     io = ExcelFile(
#     482         io,
#     483         storage_options=storage_options,
#     484         engine=engine,
#     485         engine_kwargs=engine_kwargs,
#     486     )
# ...
